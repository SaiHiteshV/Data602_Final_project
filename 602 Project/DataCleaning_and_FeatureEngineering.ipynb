# %% [markdown]
# ### Problem Statement
# Understanding the vehicle crashes dataset of New York and develop a multiclass classifier to classify the contributing factor for those crashes

# %% [markdown]
# ### About the data:
# The Motor Vehicle Collisions vehicle table contains details on each vehicle involved in the crash. Each row represents a motor vehicle involved in a crash. The data in this table goes back to April 2016 when crash reporting switched to an electronic system.
#
# The Motor Vehicle Collisions data tables contain information from all police reported motor vehicle collisions in NYC. The police report (MV104-AN) is required to be filled out for collisions where someone is injured or killed, or where there is at least $1000 worth of damage.
#
#     Column Name                   Description
#     UNIQUE_ID	                 Unique record code generated by system.
#     COLLISION_ID	              Crash identification code. Foreign Key, matches unique_id from the Crash table.
#     CRASH_DATE	                Occurrence date of collision
#     CRASH_TIME	                Occurrence time of collision
#     VEHICLE_ID	                Vehicle identification code assigned by system
#     STATE_REGISTRATION	        State where vehicle is registered.
#     VEHICLE_TYPE	              Type of vehicle based on the selected vehicle category
#     VEHICLE_MAKE	              Vehicle make
#     VEHICLE_MODEL	             Vehicle model
#     VEHICLE_YEAR	              Year the vehicle was manufactured
#     TRAVEL_DIRECTION	          Direction vehicle was traveling
#     VEHICLE_OCCUPANTS	         Number of vehicle occupants
#     DRIVER_SEX	                Gender of driver
#     DRIVER_LICENSE_STATUS	     License, permit, unlicensed
#     DRIVER_LICENSE_JURISDICTION   State where driver license was issued.
#     PRE_CRASH Pre-crash action:   Going straight, making right turn, passing, backing, etc.
#     POINT_OF_IMPACT	           Location on the vehicle of the initial point of impact
#     VEHICLE_DAMAGE	            Location on the vehicle where most of the damage occurred
#     VEHICLE_DAMAGE_1	          Additional damage locations on the vehicle
#     VEHICLE_DAMAGE_2	          Additional damage locations on the vehicle
#     VEHICLE_DAMAGE_3	          Additional damage locations on the vehicle
#     PUBLIC_PROPERTY_DAMAGE	    Public property damaged (Yes or No)
#     PUBLIC_PROPERTY_DAMAGE_TYPE   Type of public property damaged (ex. Sign, fence, light post, etc.)
#     CONTRIBUTING_FACTOR_1	     Factors contributing to the collision for designated vehicle
#     CONTRIBUTING_FACTOR_2	     Factors contributing to the collision for designated vehicle
#
# Dataset link: https://data.cityofnewyork.us/Public-Safety/Motor-Vehicle-Collisions-Vehicles/bm4k-52h4

# %% [markdown]
# ### Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ### Importing the dataset

# %%
dataset = pd.read_csv('Data.csv', delimiter=';', error_bad_lines=False, low_memory=False)

# %%
dataset.head(3).T
# Out:
#                                              0  \
# UNIQUE_ID                             10385780
# COLLISION_ID                            100201
# CRASH_DATE                          09/07/2012
# CRASH_TIME                                9:03
# VEHICLE_ID                                   1
# STATE_REGISTRATION                          NY
# VEHICLE_TYPE                 PASSENGER VEHICLE
# VEHICLE_MAKE                               NaN
# VEHICLE_MODEL                              NaN
# VEHICLE_YEAR                               NaN
# TRAVEL_DIRECTION                           NaN
# VEHICLE_OCCUPANTS                          NaN
# DRIVER_SEX                                 NaN
# DRIVER_LICENSE_STATUS                      NaN
# DRIVER_LICENSE_JURISDICTION                NaN
# PRE_CRASH                                  NaN
# POINT_OF_IMPACT                            NaN
# VEHICLE_DAMAGE                             NaN
# VEHICLE_DAMAGE_1                           NaN
# VEHICLE_DAMAGE_2                           NaN
# VEHICLE_DAMAGE_3                           NaN
# PUBLIC_PROPERTY_DAMAGE                     NaN
# PUBLIC_PROPERTY_DAMAGE_TYPE                NaN
# CONTRIBUTING_FACTOR_1              Unspecified
# CONTRIBUTING_FACTOR_2                      NaN
#
#                                                                 1  \
# UNIQUE_ID                                                19140702
# COLLISION_ID                                              4213082
# CRASH_DATE                                             09/23/2019
# CRASH_TIME                                                   8:15
# VEHICLE_ID                   0553ab4d-9500-4cba-8d98-f4d7f89d5856
# STATE_REGISTRATION                                             NY
# VEHICLE_TYPE                  Station Wagon/Sport Utility Vehicle
# VEHICLE_MAKE                                        TOYT -CAR/SUV
# VEHICLE_MODEL                                                 NaN
# VEHICLE_YEAR                                               2002.0
# TRAVEL_DIRECTION                                            North
# VEHICLE_OCCUPANTS                                               1
# DRIVER_SEX                                                      M
# DRIVER_LICENSE_STATUS                                    Licensed
# DRIVER_LICENSE_JURISDICTION                                    NY
# PRE_CRASH                                    Going Straight Ahead
# POINT_OF_IMPACT                                 Left Front Bumper
# VEHICLE_DAMAGE                           Left Front Quarter Panel
# VEHICLE_DAMAGE_1                                              NaN
# VEHICLE_DAMAGE_2                                              NaN
# VEHICLE_DAMAGE_3                                              NaN
# PUBLIC_PROPERTY_DAMAGE                                          N
# PUBLIC_PROPERTY_DAMAGE_TYPE                                   NaN
# CONTRIBUTING_FACTOR_1              Driver Inattention/Distraction
# CONTRIBUTING_FACTOR_2                                 Unspecified
#
#                                                           2
# UNIQUE_ID                                          14887647
# COLLISION_ID                                        3307608
# CRASH_DATE                                       10/02/2015
# CRASH_TIME                                            17:18
# VEHICLE_ID                                                2
# STATE_REGISTRATION                                       NY
# VEHICLE_TYPE                                           TAXI
# VEHICLE_MAKE                                            NaN
# VEHICLE_MODEL                                           NaN
# VEHICLE_YEAR                                            NaN
# TRAVEL_DIRECTION                                        NaN
# VEHICLE_OCCUPANTS                                       NaN
# DRIVER_SEX                                              NaN
# DRIVER_LICENSE_STATUS                                   NaN
# DRIVER_LICENSE_JURISDICTION                             NaN
# PRE_CRASH                              Going Straight Ahead
# POINT_OF_IMPACT                                         NaN
# VEHICLE_DAMAGE                                          NaN
# VEHICLE_DAMAGE_1                                        NaN
# VEHICLE_DAMAGE_2                                        NaN
# VEHICLE_DAMAGE_3                                        NaN
# PUBLIC_PROPERTY_DAMAGE                                  NaN
# PUBLIC_PROPERTY_DAMAGE_TYPE                             NaN
# CONTRIBUTING_FACTOR_1        Driver Inattention/Distraction
# CONTRIBUTING_FACTOR_2                                   NaN

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3683400 entries, 0 to 3683399
# Data columns (total 25 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   UNIQUE_ID                    int64
#  1   COLLISION_ID                 int64
#  2   CRASH_DATE                   object
#  3   CRASH_TIME                   object
#  4   VEHICLE_ID                   object
#  5   STATE_REGISTRATION           object
#  6   VEHICLE_TYPE                 object
#  7   VEHICLE_MAKE                 object
#  8   VEHICLE_MODEL                object
#  9   VEHICLE_YEAR                 float64
#  10  TRAVEL_DIRECTION             object
#  11  VEHICLE_OCCUPANTS            object
#  12  DRIVER_SEX                   object
#  13  DRIVER_LICENSE_STATUS        object
#  14  DRIVER_LICENSE_JURISDICTION  object
#  15  PRE_CRASH                    object
#  16  POINT_OF_IMPACT              object
#  17  VEHICLE_DAMAGE               object
#  18  VEHICLE_DAMAGE_1             object
#  19  VEHICLE_DAMAGE_2             object
#  20  VEHICLE_DAMAGE_3             object
#  21  PUBLIC_PROPERTY_DAMAGE       object
#  22  PUBLIC_PROPERTY_DAMAGE_TYPE  object
#  23  CONTRIBUTING_FACTOR_1        object
#  24  CONTRIBUTING_FACTOR_2        object
# dtypes: float64(1), int64(2), object(22)
# memory usage: 702.6+ MB

# %%
dataset.describe()
# Out:
#           UNIQUE_ID  COLLISION_ID  VEHICLE_YEAR
# count  3.683400e+06  3.683400e+06  1.890871e+06
# mean   1.603776e+07  2.988207e+06  2.014800e+03
# std    3.239644e+06  1.495392e+06  1.556035e+02
# min    1.117110e+05  2.200000e+01  1.000000e+03
# 25%    1.420989e+07  2.998459e+06  2.008000e+03
# 50%    1.729543e+07  3.561780e+06  2.013000e+03
# 75%    1.872298e+07  4.019685e+06  2.016000e+03
# max    2.009909e+07  4.473929e+06  2.006300e+04

# %% [markdown]
# ### Data Cleaning & Data Feature Engineering

# %% [markdown]
# ### Understanding Missing Values Distribution

# %%
dataset.isna().sum().sort_values().plot(kind = 'bar', figsize=(15,10))
plt.gcf().set_size_inches(15,10)
plt.title('Displaying NAN count')
plt.xlabel('Column name')
plt.ylabel('Count')
plt.show()

# %%
dataset.isnull().sum() * 100 / len(dataset)
# Out:
# UNIQUE_ID                       0.000000
# COLLISION_ID                    0.000000
# CRASH_DATE                      0.000000
# CRASH_TIME                      0.000000
# VEHICLE_ID                      0.000000
# STATE_REGISTRATION              5.789488
# VEHICLE_TYPE                    4.755118
# VEHICLE_MAKE                   48.362328
# VEHICLE_MODEL                  98.605256
# VEHICLE_YEAR                   48.665065
# TRAVEL_DIRECTION               44.330537
# VEHICLE_OCCUPANTS              46.572623
# DRIVER_SEX                     55.455123
# DRIVER_LICENSE_STATUS          57.272113
# DRIVER_LICENSE_JURISDICTION    57.058832
# PRE_CRASH                      23.913097
# POINT_OF_IMPACT                45.070668
# VEHICLE_DAMAGE                 45.522914
# VEHICLE_DAMAGE_1               65.392192
# VEHICLE_DAMAGE_2               74.262421
# VEHICLE_DAMAGE_3               80.434001
# PUBLIC_PROPERTY_DAMAGE         41.506842
# PUBLIC_PROPERTY_DAMAGE_TYPE    99.483249
# CONTRIBUTING_FACTOR_1           3.160993
# CONTRIBUTING_FACTOR_2          44.768882
# dtype: float64

# %% [markdown]
# ### Observations
# - There are very few rows like unique_id, collision_id, date and time with no missing data.
# - Columns such as VEHICLE_MODEL, VEHICLE_DAMAGE_1, VEHICLE_DAMAGE_2, VEHICLE_DAMAGE_3, PUBLIC_PROPERTY_DAMAGE_TYPE have more than 65% of missing values.

# %% [markdown]
# ### Understanding the Contributing factor distribution

# %%
dataset.CONTRIBUTING_FACTOR_1.value_counts().head()
# Out:
# Unspecified                       2121223
# Driver Inattention/Distraction     441483
# Failure to Yield Right-of-Way      122919
# Following Too Closely              113854
# Other Vehicular                     90232
# Name: CONTRIBUTING_FACTOR_1, dtype: int64

# %%
dataset.CONTRIBUTING_FACTOR_1 = dataset.CONTRIBUTING_FACTOR_1.str.lower()
dataset.CONTRIBUTING_FACTOR_2 = dataset.CONTRIBUTING_FACTOR_2.str.lower()

def contributing_factor(factor1,factor2):
    if factor1 == 'unspecified':
        return factor2
    else:
        return factor1

# %%
dataset['CONTRIBUTING_FACTOR_1'] = dataset.apply(lambda x :contributing_factor(x['CONTRIBUTING_FACTOR_1'], 
                                                                               x['CONTRIBUTING_FACTOR_2']), axis=1)

# %%
dataset.CONTRIBUTING_FACTOR_1.value_counts().head()
# Out:
# unspecified                       1064433
# driver inattention/distraction     444416
# failure to yield right-of-way      123601
# following too closely              115340
# other vehicular                     91575
# Name: CONTRIBUTING_FACTOR_1, dtype: int64

# %% [markdown]
# ### Observations
# - Reduced the number of rows with values 'Unspecified' by 49.8%.

# %% [markdown]
# ### Property demage  Distribution

# %%
sns.countplot(x='PUBLIC_PROPERTY_DAMAGE', palette="pastel", data=dataset)
plt.gcf().set_size_inches(20,10)
plt.title('Property demage  Distribution')
plt.xlabel('Property demage')
plt.xticks(rotation='vertical')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Observations
# - More than 90% of the data has 'No' that means in more than 90% of crashes there was no property damage.

# %% [markdown]
# ### Vehicle Damage  Distribution

# %%
sns.countplot(x='VEHICLE_DAMAGE', palette="pastel", data=dataset, order=dataset.VEHICLE_DAMAGE.value_counts().index)
plt.gcf().set_size_inches(20,10)
plt.title('Vehicle Damage  Distribution')
plt.xlabel('Vehicle Damage')
plt.xticks(rotation='vertical')
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(x='VEHICLE_DAMAGE_1', palette="pastel", data=dataset, order=dataset.VEHICLE_DAMAGE_1.value_counts().index)
plt.gcf().set_size_inches(20,10)
plt.title('Vehicle Damage 1  Distribution')
plt.xlabel('Vehicle Damage')
plt.xticks(rotation='vertical')
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(x='VEHICLE_DAMAGE_2', palette="pastel", data=dataset, order=dataset.VEHICLE_DAMAGE_2.value_counts().index)
plt.gcf().set_size_inches(20,10)
plt.title('Vehicle Damage 2  Distribution')
plt.xlabel('Vehicle Damage')
plt.xticks(rotation='vertical')
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(x='VEHICLE_DAMAGE_3', palette="pastel", data=dataset, order=dataset.VEHICLE_DAMAGE_3.value_counts().index)
plt.gcf().set_size_inches(20,10)
plt.title('Vehicle Damage 3  Distribution')
plt.xlabel('Vehicle Damagen')
plt.xticks(rotation='vertical')
plt.ylabel('Count')
plt.show()

# %%
# trying to decrease the number of missing values
def vehicle_damage(damage1, damage2, damage3, damage4):
    if not pd.isna(damage1):
        return damage1
    elif not pd.isna(damage2):
        return damage2
    elif not pd.isna(damage3):
        return damage3
    else:
        return damage4

# %%
dataset['VEHICLE_DAMAGE_cleaned'] = dataset.apply(lambda x :vehicle_damage(x['VEHICLE_DAMAGE'], x['VEHICLE_DAMAGE_1'],
                                                                  x['VEHICLE_DAMAGE_2'], x['VEHICLE_DAMAGE_3']), axis=1)

# %%
dataset.VEHICLE_DAMAGE_cleaned = dataset.VEHICLE_DAMAGE_cleaned.str.lower()
sns.countplot(x='VEHICLE_DAMAGE', palette="pastel", data=dataset, order=dataset.VEHICLE_DAMAGE.value_counts().index)
plt.gcf().set_size_inches(20,10)
plt.title('Road condition  Distribution')
plt.xlabel('Road condition')
plt.xticks(rotation='vertical')
plt.ylabel('Count')
plt.show()
print(dataset.VEHICLE_DAMAGE_cleaned.isnull().sum() * 100 / len(dataset))
# Out:
# 45.511212466742684

# %%
dataset.POINT_OF_IMPACT = dataset.POINT_OF_IMPACT.str.lower()
sns.countplot(x='POINT_OF_IMPACT', palette="pastel", data=dataset, order=dataset.POINT_OF_IMPACT.value_counts().index)
plt.gcf().set_size_inches(20,10)
plt.title('Point of Impact  Distribution')
plt.xlabel('Point of Impact')
plt.xticks(rotation='vertical')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Observations
# - Most of the damages have occured at the front end of the car compared to other parts.

# %% [markdown]
# ### Pre Crash action Distribution

# %%
dataset.PRE_CRASH = dataset.PRE_CRASH.str.lower()
sns.countplot(x='PRE_CRASH', palette="pastel", data=dataset, order=dataset.PRE_CRASH.value_counts().index)
plt.gcf().set_size_inches(20,10)
plt.title('Pre Crash action Distribution')
plt.xlabel('Pre Crash action')
plt.xticks(rotation='vertical')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Observations
# - A great portion of cars that were involved in an accident were either going straight or were parked.

# %% [markdown]
# ### Drivers License Status Distribution

# %%
sns.countplot(x='DRIVER_LICENSE_STATUS', palette="pastel", data=dataset, order=dataset.DRIVER_LICENSE_STATUS.value_counts().index)
plt.gcf().set_size_inches(20,10)
plt.title('DRIVER_LICENSE_STATUS Distribution')
plt.xlabel('DRIVER_LICENSE_STATUS')
plt.xticks(rotation='vertical')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Observations
# - About 95% of people who were involved in an accident are licensed.

# %% [markdown]
# ### Driver Sex Distribution

# %%
sns.countplot(x='DRIVER_SEX', palette="pastel", data=dataset, order=dataset.DRIVER_SEX.value_counts().index)
plt.gcf().set_size_inches(20,10)
plt.title('DRIVER_SEX Distribution')
plt.xlabel('DRIVER_SEX')
plt.xticks(rotation='vertical')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Observations
# - Majority of accidents were caused by Males.

# %% [markdown]
# ### Understanding the vehicle occupants distribtion.

# %%
sns.countplot(x='VEHICLE_OCCUPANTS', palette="pastel", data=dataset, order=dataset.VEHICLE_OCCUPANTS.value_counts().index)
plt.gcf().set_size_inches(20,10)
plt.title('Vehicle Occupants Distribution')
plt.xlabel('Number of people in vehicle')
plt.xticks(rotation='vertical')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Cleaning the vehicle occupants distribtion

# %%
occupants_ls = ['1','2','3','4','0']
dataset = dataset[dataset.VEHICLE_OCCUPANTS.isin(occupants_ls)]
sns.countplot(x='VEHICLE_OCCUPANTS', palette="pastel", data=dataset, order=dataset.VEHICLE_OCCUPANTS.value_counts().index)
plt.gcf().set_size_inches(20,10)
plt.title('Vehicle Occupants Distribution')
plt.xlabel('Number of people in vehicle')
plt.xticks(rotation='vertical')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Observations
# - In 80% of the cases there is only one person in the vehicle which was involved in an accident.

# %% [markdown]
# ### Vehicle Year Distribution

# %%
sns.countplot(x='VEHICLE_YEAR', palette="pastel", data=dataset, order=dataset.VEHICLE_YEAR.value_counts().index)
plt.gcf().set_size_inches(20,10)
plt.title('Vehicle Year Distribution')
plt.xlabel('Vehicle Year')
plt.xticks(rotation='vertical')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Cleaning the Vehicle Year Distribution column.

# %%
dataset = dataset[dataset.VEHICLE_YEAR >=1990]
dataset = dataset[dataset.VEHICLE_YEAR <=2021]
sns.countplot(x='VEHICLE_YEAR', palette="pastel", data=dataset, order=dataset.VEHICLE_YEAR.value_counts().index)
plt.gcf().set_size_inches(20,10)
plt.title('Vehicle Year Distribution')
plt.xlabel('Vehicle Year')
plt.xticks(rotation='vertical')
plt.ylabel('Count')
plt.show()

# %%
dataset['how_old'] = 2021 - dataset.VEHICLE_YEAR
dataset.head(2).T
# Out:
#                                                                 1  \
# UNIQUE_ID                                                19140702
# COLLISION_ID                                              4213082
# CRASH_DATE                                             09/23/2019
# CRASH_TIME                                                   8:15
# VEHICLE_ID                   0553ab4d-9500-4cba-8d98-f4d7f89d5856
# STATE_REGISTRATION                                             NY
# VEHICLE_TYPE                  Station Wagon/Sport Utility Vehicle
# VEHICLE_MAKE                                        TOYT -CAR/SUV
# VEHICLE_MODEL                                                 NaN
# VEHICLE_YEAR                                               2002.0
# TRAVEL_DIRECTION                                            North
# VEHICLE_OCCUPANTS                                               1
# DRIVER_SEX                                                      M
# DRIVER_LICENSE_STATUS                                    Licensed
# DRIVER_LICENSE_JURISDICTION                                    NY
# PRE_CRASH                                    going straight ahead
# POINT_OF_IMPACT                                 left front bumper
# VEHICLE_DAMAGE                           Left Front Quarter Panel
# VEHICLE_DAMAGE_1                                              NaN
# VEHICLE_DAMAGE_2                                              NaN
# VEHICLE_DAMAGE_3                                              NaN
# PUBLIC_PROPERTY_DAMAGE                                          N
# PUBLIC_PROPERTY_DAMAGE_TYPE                                   NaN
# CONTRIBUTING_FACTOR_1              driver inattention/distraction
# CONTRIBUTING_FACTOR_2                                 unspecified
# VEHICLE_DAMAGE_cleaned                   left front quarter panel
# how_old                                                      19.0
#
#                                                           5
# UNIQUE_ID                                          17044639
# COLLISION_ID                                        3434155
# CRASH_DATE                                       05/02/2016
# CRASH_TIME                                            17:35
# VEHICLE_ID                                           219456
# STATE_REGISTRATION                                       NY
# VEHICLE_TYPE                                     4 dr sedan
# VEHICLE_MAKE                                  MERZ -CAR/SUV
# VEHICLE_MODEL                                           NaN
# VEHICLE_YEAR                                         2015.0
# TRAVEL_DIRECTION                                       East
# VEHICLE_OCCUPANTS                                         2
# DRIVER_SEX                                                M
# DRIVER_LICENSE_STATUS                              Licensed
# DRIVER_LICENSE_JURISDICTION                              FL
# PRE_CRASH                                           merging
# POINT_OF_IMPACT                          right front bumper
# VEHICLE_DAMAGE                           Right Front Bumper
# VEHICLE_DAMAGE_1                  Right Front Quarter Panel
# VEHICLE_DAMAGE_2                                        NaN
# VEHICLE_DAMAGE_3                                        NaN
# PUBLIC_PROPERTY_DAMAGE                                    N
# PUBLIC_PROPERTY_DAMAGE_TYPE                             NaN
# CONTRIBUTING_FACTOR_1        driver inattention/distraction
# CONTRIBUTING_FACTOR_2                  unsafe lane changing
# VEHICLE_DAMAGE_cleaned                   right front bumper
# how_old                                                 6.0

# %% [markdown]
# ### Cleaning the vehicle type and vehicle make columns.

# %%
dataset.VEHICLE_TYPE = dataset.VEHICLE_TYPE.str.lower()
dataset.VEHICLE_MAKE = dataset.VEHICLE_MAKE.str.lower()

# %%
dataset.VEHICLE_TYPE = dataset.VEHICLE_TYPE.str.lower()
dataset.loc[dataset['VEHICLE_TYPE']=='sport utility / station wagon', 'VEHICLE_TYPE'] = 'station wagon/sport utility vehicle'
dataset.loc[dataset['VEHICLE_TYPE']=='4 dr sedan', 'VEHICLE_TYPE'] = 'sedan'
dataset.loc[dataset['VEHICLE_TYPE']=='motorcycle', 'VEHICLE_TYPE'] = 'bike'

# %%
dataset.VEHICLE_TYPE.value_counts().loc[lambda x : x>10000].plot(kind='bar', figsize=(15,10))
plt.title('Vehicle Type Distribution')
plt.xlabel('Vehicle Type')
plt.ylabel('Count')
plt.show()

# %%
dataset["MAKE"] = dataset.VEHICLE_MAKE.str.split(" ", n = 1, expand = True)[0]
dataset["MAKE"] = dataset.MAKE.str.split("-", n = 1, expand = True)[0]
dataset.head(2)
# Out:
#    UNIQUE_ID  COLLISION_ID  CRASH_DATE CRASH_TIME  \
# 1   19140702       4213082  09/23/2019       8:15
# 5   17044639       3434155  05/02/2016      17:35
#
#                              VEHICLE_ID STATE_REGISTRATION  \
# 1  0553ab4d-9500-4cba-8d98-f4d7f89d5856                 NY
# 5                                219456                 NY
#
#                           VEHICLE_TYPE   VEHICLE_MAKE VEHICLE_MODEL  \
# 1  station wagon/sport utility vehicle  toyt -car/suv           NaN
# 5                                sedan  merz -car/suv           NaN
#
#    VEHICLE_YEAR  ...           VEHICLE_DAMAGE_1 VEHICLE_DAMAGE_2  \
# 1        2002.0  ...                        NaN              NaN
# 5        2015.0  ...  Right Front Quarter Panel              NaN
#
#   VEHICLE_DAMAGE_3 PUBLIC_PROPERTY_DAMAGE PUBLIC_PROPERTY_DAMAGE_TYPE  \
# 1              NaN                      N                         NaN
# 5              NaN                      N                         NaN
#
#             CONTRIBUTING_FACTOR_1 CONTRIBUTING_FACTOR_2  \
# 1  driver inattention/distraction           unspecified
# 5  driver inattention/distraction  unsafe lane changing
#
#      VEHICLE_DAMAGE_cleaned how_old  MAKE
# 1  left front quarter panel    19.0  toyt
# 5        right front bumper     6.0  merz
#
# [2 rows x 28 columns]

# %% [markdown]
# ### Cleaning the crash date and crash time columns

# %%
dataset['CRASH_DATE'] =  pd.to_datetime(dataset['CRASH_DATE'], format='%m/%d/%Y')
dataset['CRASH_TIME'] =  pd.to_datetime(dataset['CRASH_TIME'], format='%H:%M').dt.time
dataset['Year'] = pd.to_datetime(dataset['CRASH_DATE'], format='%m/%d/%Y').dt.year
dataset['Month'] = pd.to_datetime(dataset['CRASH_DATE'], format='%m/%d/%Y').dt.month
dataset['Week'] = pd.to_datetime(dataset['CRASH_DATE'], format='%m/%d/%Y').apply(lambda d: (d.day-1) // 7 + 1)
dataset['Hour'] = pd.to_datetime(dataset['CRASH_TIME'], format='%H:%M:%S').dt.hour
dataset = dataset[dataset.Year>2015]

# %%
dataset.head().T
# Out:
#                                                                1   \
# UNIQUE_ID                                                19140702
# COLLISION_ID                                              4213082
# CRASH_DATE                                    2019-09-23 00:00:00
# CRASH_TIME                                               08:15:00
# VEHICLE_ID                   0553ab4d-9500-4cba-8d98-f4d7f89d5856
# STATE_REGISTRATION                                             NY
# VEHICLE_TYPE                  station wagon/sport utility vehicle
# VEHICLE_MAKE                                        toyt -car/suv
# VEHICLE_MODEL                                                 NaN
# VEHICLE_YEAR                                               2002.0
# TRAVEL_DIRECTION                                            North
# VEHICLE_OCCUPANTS                                               1
# DRIVER_SEX                                                      M
# DRIVER_LICENSE_STATUS                                    Licensed
# DRIVER_LICENSE_JURISDICTION                                    NY
# PRE_CRASH                                    going straight ahead
# POINT_OF_IMPACT                                 left front bumper
# VEHICLE_DAMAGE                           Left Front Quarter Panel
# VEHICLE_DAMAGE_1                                              NaN
# VEHICLE_DAMAGE_2                                              NaN
# VEHICLE_DAMAGE_3                                              NaN
# PUBLIC_PROPERTY_DAMAGE                                          N
# PUBLIC_PROPERTY_DAMAGE_TYPE                                   NaN
# CONTRIBUTING_FACTOR_1              driver inattention/distraction
# CONTRIBUTING_FACTOR_2                                 unspecified
# VEHICLE_DAMAGE_cleaned                   left front quarter panel
# how_old                                                      19.0
# MAKE                                                         toyt
# Year                                                         2019
# Month                                                           9
# Week                                                            4
# Hour                                                            8
#
#                                                          5   \
# UNIQUE_ID                                          17044639
# COLLISION_ID                                        3434155
# CRASH_DATE                              2016-05-02 00:00:00
# CRASH_TIME                                         17:35:00
# VEHICLE_ID                                           219456
# STATE_REGISTRATION                                       NY
# VEHICLE_TYPE                                          sedan
# VEHICLE_MAKE                                  merz -car/suv
# VEHICLE_MODEL                                           NaN
# VEHICLE_YEAR                                         2015.0
# TRAVEL_DIRECTION                                       East
# VEHICLE_OCCUPANTS                                         2
# DRIVER_SEX                                                M
# DRIVER_LICENSE_STATUS                              Licensed
# DRIVER_LICENSE_JURISDICTION                              FL
# PRE_CRASH                                           merging
# POINT_OF_IMPACT                          right front bumper
# VEHICLE_DAMAGE                           Right Front Bumper
# VEHICLE_DAMAGE_1                  Right Front Quarter Panel
# VEHICLE_DAMAGE_2                                        NaN
# VEHICLE_DAMAGE_3                                        NaN
# PUBLIC_PROPERTY_DAMAGE                                    N
# PUBLIC_PROPERTY_DAMAGE_TYPE                             NaN
# CONTRIBUTING_FACTOR_1        driver inattention/distraction
# CONTRIBUTING_FACTOR_2                  unsafe lane changing
# VEHICLE_DAMAGE_cleaned                   right front bumper
# how_old                                                 6.0
# MAKE                                                   merz
# Year                                                   2016
# Month                                                     5
# Week                                                      1
# Hour                                                     17
#
#                                                               7   \
# UNIQUE_ID                                               17303317
# COLLISION_ID                                             3503027
# CRASH_DATE                                   2016-08-18 00:00:00
# CRASH_TIME                                              12:39:00
# VEHICLE_ID                                                672828
# STATE_REGISTRATION                                            NY
# VEHICLE_TYPE                 station wagon/sport utility vehicle
# VEHICLE_MAKE                                       ford -car/suv
# VEHICLE_MODEL                                                NaN
# VEHICLE_YEAR                                              2005.0
# TRAVEL_DIRECTION                                       Southwest
# VEHICLE_OCCUPANTS                                              2
# DRIVER_SEX                                                     F
# DRIVER_LICENSE_STATUS                                   Licensed
# DRIVER_LICENSE_JURISDICTION                                   NY
# PRE_CRASH                                   going straight ahead
# POINT_OF_IMPACT                                 center front end
# VEHICLE_DAMAGE                                  Center Front End
# VEHICLE_DAMAGE_1                                       No Damage
# VEHICLE_DAMAGE_2                                       No Damage
# VEHICLE_DAMAGE_3                                       No Damage
# PUBLIC_PROPERTY_DAMAGE                                         N
# PUBLIC_PROPERTY_DAMAGE_TYPE                                  NaN
# CONTRIBUTING_FACTOR_1             driver inattention/distraction
# CONTRIBUTING_FACTOR_2                                unspecified
# VEHICLE_DAMAGE_cleaned                          center front end
# how_old                                                     16.0
# MAKE                                                        ford
# Year                                                        2016
# Month                                                          8
# Week                                                           3
# Hour                                                          12
#
#                                               10                       12
# UNIQUE_ID                               17285715                 17307366
# COLLISION_ID                             3487936                  3499697
# CRASH_DATE                   2016-07-22 00:00:00      2016-08-13 00:00:00
# CRASH_TIME                              15:40:00                 21:05:00
# VEHICLE_ID                                554272                   650962
# STATE_REGISTRATION                            NY                       NY
# VEHICLE_TYPE                         convertible                    sedan
# VEHICLE_MAKE                       volk -car/suv            niss -car/suv
# VEHICLE_MODEL                                NaN                      NaN
# VEHICLE_YEAR                              2013.0                   2015.0
# TRAVEL_DIRECTION                           South                     West
# VEHICLE_OCCUPANTS                              1                        2
# DRIVER_SEX                                     M                        F
# DRIVER_LICENSE_STATUS                   Licensed                 Licensed
# DRIVER_LICENSE_JURISDICTION                   NY                       NY
# PRE_CRASH                     stopped in traffic     going straight ahead
# POINT_OF_IMPACT                right rear bumper          left side doors
# VEHICLE_DAMAGE                 Right Rear Bumper          Left Side Doors
# VEHICLE_DAMAGE_1                 Center Back End  Left Rear Quarter Panel
# VEHICLE_DAMAGE_2                Left Rear Bumper                      NaN
# VEHICLE_DAMAGE_3                             NaN                      NaN
# PUBLIC_PROPERTY_DAMAGE                         N                        N
# PUBLIC_PROPERTY_DAMAGE_TYPE                  NaN                      NaN
# CONTRIBUTING_FACTOR_1                unspecified              unspecified
# CONTRIBUTING_FACTOR_2                unspecified              unspecified
# VEHICLE_DAMAGE_cleaned         right rear bumper          left side doors
# how_old                                      8.0                      6.0
# MAKE                                        volk                     niss
# Year                                        2016                     2016
# Month                                          7                        8
# Week                                           4                        2
# Hour                                          15                       21

# %% [markdown]
# ### Droping the unnecessary columns
# - UNIQUE_ID, COLLISION_ID, and VEHICLE_ID as they are unique and don't add value for this analysis.
# - CRASH_DATE, CRASH_TIME, VEHICLE_YEAR, CONTRIBUTING_FACTOR_2, and VEHICLE_MAKE as we extracted the main information from them.
# - VEHICLE_MODEL, PUBLIC_PROPERTY_DAMAGE, PUBLIC_PROPERTY_DAMAGE_TYPE as most of the data is missing.
# - STATE_REGISTRATION, DRIVER_LICENSE_STATUS, TRAVEL_DIRECTION, and DRIVER_LICENSE_JURISDICTION as data is highly skewed
# - VEHICLE_DAMAGE_cleaned as POINT_OF_IMPACT and VEHICLE_DAMAGE_cleaned very highly correlated.

# %%
dataset.drop(['UNIQUE_ID','COLLISION_ID','CRASH_DATE','CRASH_TIME','VEHICLE_ID','STATE_REGISTRATION','VEHICLE_MAKE','VEHICLE_MODEL',
              'VEHICLE_YEAR','TRAVEL_DIRECTION','DRIVER_LICENSE_STATUS','DRIVER_LICENSE_JURISDICTION','VEHICLE_DAMAGE',
              'VEHICLE_DAMAGE_1','VEHICLE_DAMAGE_2','VEHICLE_DAMAGE_3','VEHICLE_DAMAGE_cleaned','PUBLIC_PROPERTY_DAMAGE', 
              'PUBLIC_PROPERTY_DAMAGE_TYPE','CONTRIBUTING_FACTOR_2'],axis=1,inplace=True)

# %%
dataset.columns
# Out:
# Index(['VEHICLE_TYPE', 'VEHICLE_OCCUPANTS', 'DRIVER_SEX', 'PRE_CRASH',
#        'POINT_OF_IMPACT', 'CONTRIBUTING_FACTOR_1', 'how_old', 'MAKE', 'Year',
#        'Month', 'Week', 'Hour'],
#       dtype='object')

# %%
len(dataset)
# Out:
# 1844571

# %% [markdown]
# ### Dropping NaN values

# %%
dataset.dropna(how='any', inplace=True)

# %%
len(dataset)
# Out:
# 1533711

# %%
dataset.head()
# Out:
#                            VEHICLE_TYPE VEHICLE_OCCUPANTS DRIVER_SEX  \
# 1   station wagon/sport utility vehicle                 1          M
# 5                                 sedan                 2          M
# 7   station wagon/sport utility vehicle                 2          F
# 10                          convertible                 1          M
# 12                                sedan                 2          F
#
#                PRE_CRASH     POINT_OF_IMPACT           CONTRIBUTING_FACTOR_1  \
# 1   going straight ahead   left front bumper  driver inattention/distraction
# 5                merging  right front bumper  driver inattention/distraction
# 7   going straight ahead    center front end  driver inattention/distraction
# 10    stopped in traffic   right rear bumper                     unspecified
# 12  going straight ahead     left side doors                     unspecified
#
#     how_old  MAKE  Year  Month  Week  Hour
# 1      19.0  toyt  2019      9     4     8
# 5       6.0  merz  2016      5     1    17
# 7      16.0  ford  2016      8     3    12
# 10      8.0  volk  2016      7     4    15
# 12      6.0  niss  2016      8     2    21

# %% [markdown]
# ### Overall cleaning of the dataset

# %%
dataset.MAKE.value_counts()
# Out:
# toyt          282757
# hond          185868
# niss          158978
# ford          152329
# chev           77093
#                ...
# pathfinder         1
# vgar               1
# st/a               1
# strick             1
# amig               1
# Name: MAKE, Length: 3421, dtype: int64

# %%
dataset.PRE_CRASH.value_counts()
# Out:
# going straight ahead          828152
# parked                        111608
# making left turn              108051
# stopped in traffic             92596
# making right turn              88521
# slowing or stopping            68028
# backing                        54724
# changing lanes                 53368
# starting from parking          29604
# merging                        29572
# entering parked position       22690
# making u turn                  14783
# passing                        12595
# other*                          9579
# starting in traffic             7282
# avoiding object in roadway      1736
# police pursuit                   325
# making left turn on red          300
# making right turn on red         197
# Name: PRE_CRASH, dtype: int64

# %%
dataset.POINT_OF_IMPACT.value_counts()
# Out:
# center front end             255512
# left front bumper            198525
# center back end              198460
# right front bumper           182858
# right front quarter panel    121983
# left front quarter panel     106226
# left rear quarter panel       80879
# left side doors               78163
# right side doors              74346
# left rear bumper              72693
# right rear quarter panel      67216
# right rear bumper             56015
# no damage                     23689
# other                          9423
# trailer                        2746
# roof                           2203
# undercarriage                  1142
# overturned                      953
# demolished                      679
# Name: POINT_OF_IMPACT, dtype: int64

# %%
dataset.CONTRIBUTING_FACTOR_1.value_counts()
# Out:
# unspecified                                              759739
# driver inattention/distraction                           251207
# following too closely                                     96709
# failure to yield right-of-way                             69025
# passing or lane usage improper                            41243
# backing unsafely                                          38325
# other vehicular                                           37072
# unsafe lane changing                                      35550
# passing too closely                                       32838
# turning improperly                                        23531
# reaction to uninvolved vehicle                            19350
# driver inexperience                                       17300
# traffic control disregarded                               17030
# unsafe speed                                              15317
# alcohol involvement                                       12120
# pavement slippery                                         10961
# view obstructed/limited                                    9760
# oversized vehicle                                          6445
# pedestrian/bicyclist/other pedestrian error/confusion      4428
# brakes defective                                           3763
# fell asleep                                                3479
# passenger distraction                                      3434
# aggressive driving/road rage                               2776
# outside car distraction                                    2643
# glare                                                      2418
# obstruction/debris                                         2234
# steering failure                                           1567
# tire failure/inadequate                                    1399
# failure to keep right                                      1276
# pavement defective                                         1238
# fatigued/drowsy                                            1224
# illnes                                                     1221
# lost consciousness                                         1106
# animals action                                              956
# lane marking improper/inadequate                            771
# drugs (illegal)                                             657
# traffic control device improper/non-working                 597
# accelerator defective                                       584
# driverless/runaway vehicle                                  483
# cell phone (hand-held)                                      395
# physical disability                                         304
# other electronic device                                     171
# tinted windows                                              149
# using on board navigation device                            134
# eating or drinking                                          109
# tow hitch defective                                         100
# prescription medication                                      97
# other lighting defects                                       86
# 80                                                           77
# vehicle vandalism                                            66
# cell phone (hands-free)                                      63
# headlights defective                                         56
# shoulders defective/improper                                 50
# texting                                                      32
# windshield inadequate                                        28
# listening/using headphones                                   10
# 1                                                             8
# Name: CONTRIBUTING_FACTOR_1, dtype: int64

# %%
threshold = 5000 
columns = ['VEHICLE_TYPE', 'PRE_CRASH', 'POINT_OF_IMPACT', 'MAKE' ,'CONTRIBUTING_FACTOR_1']
for col in columns:
    value_counts = dataset[col].value_counts() 
    to_remove = value_counts[value_counts <= threshold].index
    dataset[col].replace(to_remove, "other", inplace=True)

# %%
len(dataset)
# Out:
# 1533711

# %%
dataset.CONTRIBUTING_FACTOR_1.value_counts()
# Out:
# unspecified                       759739
# driver inattention/distraction    251207
# following too closely              96709
# failure to yield right-of-way      69025
# passing or lane usage improper     41243
# other                              40189
# backing unsafely                   38325
# other vehicular                    37072
# unsafe lane changing               35550
# passing too closely                32838
# turning improperly                 23531
# reaction to uninvolved vehicle     19350
# driver inexperience                17300
# traffic control disregarded        17030
# unsafe speed                       15317
# alcohol involvement                12120
# pavement slippery                  10961
# view obstructed/limited             9760
# oversized vehicle                   6445
# Name: CONTRIBUTING_FACTOR_1, dtype: int64

# %%
### dropping the rows with values 'unspecified' in contributing factor
dataset.drop(dataset[dataset['CONTRIBUTING_FACTOR_1'] == 'unspecified'].index, inplace = True)
dataset.CONTRIBUTING_FACTOR_1.value_counts()
# Out:
# driver inattention/distraction    251207
# following too closely              96709
# failure to yield right-of-way      69025
# passing or lane usage improper     41243
# other                              40189
# backing unsafely                   38325
# other vehicular                    37072
# unsafe lane changing               35550
# passing too closely                32838
# turning improperly                 23531
# reaction to uninvolved vehicle     19350
# driver inexperience                17300
# traffic control disregarded        17030
# unsafe speed                       15317
# alcohol involvement                12120
# pavement slippery                  10961
# view obstructed/limited             9760
# oversized vehicle                   6445
# Name: CONTRIBUTING_FACTOR_1, dtype: int64

# %%
len(dataset)
# Out:
# 773972

# %%
dataset.head().T
# Out:
#                                                         1   \
# VEHICLE_TYPE           station wagon/sport utility vehicle
# VEHICLE_OCCUPANTS                                        1
# DRIVER_SEX                                               M
# PRE_CRASH                             going straight ahead
# POINT_OF_IMPACT                          left front bumper
# CONTRIBUTING_FACTOR_1       driver inattention/distraction
# how_old                                               19.0
# MAKE                                                  toyt
# Year                                                  2019
# Month                                                    9
# Week                                                     4
# Hour                                                     8
#
#                                                    5   \
# VEHICLE_TYPE                                    sedan
# VEHICLE_OCCUPANTS                                   2
# DRIVER_SEX                                          M
# PRE_CRASH                                     merging
# POINT_OF_IMPACT                    right front bumper
# CONTRIBUTING_FACTOR_1  driver inattention/distraction
# how_old                                           6.0
# MAKE                                             merz
# Year                                             2016
# Month                                               5
# Week                                                1
# Hour                                               17
#
#                                                         7   \
# VEHICLE_TYPE           station wagon/sport utility vehicle
# VEHICLE_OCCUPANTS                                        2
# DRIVER_SEX                                               F
# PRE_CRASH                             going straight ahead
# POINT_OF_IMPACT                           center front end
# CONTRIBUTING_FACTOR_1       driver inattention/distraction
# how_old                                               16.0
# MAKE                                                  ford
# Year                                                  2016
# Month                                                    8
# Week                                                     3
# Hour                                                    12
#
#                                                         18  \
# VEHICLE_TYPE           station wagon/sport utility vehicle
# VEHICLE_OCCUPANTS                                        1
# DRIVER_SEX                                               M
# PRE_CRASH                                          passing
# POINT_OF_IMPACT                  right front quarter panel
# CONTRIBUTING_FACTOR_1                 unsafe lane changing
# how_old                                                6.0
# MAKE                                                  toyt
# Year                                                  2016
# Month                                                    4
# Week                                                     1
# Hour                                                    15
#
#                                                    38
# VEHICLE_TYPE                                    sedan
# VEHICLE_OCCUPANTS                                   2
# DRIVER_SEX                                          M
# PRE_CRASH                        going straight ahead
# POINT_OF_IMPACT                      center front end
# CONTRIBUTING_FACTOR_1  driver inattention/distraction
# how_old                                          13.0
# MAKE                                             toyt
# Year                                             2019
# Month                                              10
# Week                                                4
# Hour                                               10

# %%
dataset.to_csv('Cleaned_Data.csv', index=False)
