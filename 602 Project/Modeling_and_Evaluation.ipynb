# %% [markdown]
# ### Importing the libraries

# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importing the dataset

# %%
dataset = pd.read_csv('Cleaned_Data.csv')
dataset.head().T
# Out:
#                                                          0  \
# VEHICLE_TYPE           station wagon/sport utility vehicle
# VEHICLE_OCCUPANTS                                        1
# DRIVER_SEX                                               M
# PRE_CRASH                             going straight ahead
# POINT_OF_IMPACT                          left front bumper
# how_old                                                 19
# MAKE                                                  toyt
# Year                                                  2019
# Month                                                    9
# Week                                                     4
# Hour                                                     8
# CONTRIBUTING_FACTOR_1       driver inattention/distraction
#
#                                                     1  \
# VEHICLE_TYPE                                    sedan
# VEHICLE_OCCUPANTS                                   2
# DRIVER_SEX                                          M
# PRE_CRASH                                     merging
# POINT_OF_IMPACT                    right front bumper
# how_old                                             6
# MAKE                                             merz
# Year                                             2016
# Month                                               5
# Week                                                1
# Hour                                               17
# CONTRIBUTING_FACTOR_1  driver inattention/distraction
#
#                                                          2  \
# VEHICLE_TYPE           station wagon/sport utility vehicle
# VEHICLE_OCCUPANTS                                        2
# DRIVER_SEX                                               F
# PRE_CRASH                             going straight ahead
# POINT_OF_IMPACT                           center front end
# how_old                                                 16
# MAKE                                                  ford
# Year                                                  2016
# Month                                                    8
# Week                                                     3
# Hour                                                    12
# CONTRIBUTING_FACTOR_1       driver inattention/distraction
#
#                                                          3  \
# VEHICLE_TYPE           station wagon/sport utility vehicle
# VEHICLE_OCCUPANTS                                        1
# DRIVER_SEX                                               M
# PRE_CRASH                                          passing
# POINT_OF_IMPACT                  right front quarter panel
# how_old                                                  6
# MAKE                                                  toyt
# Year                                                  2016
# Month                                                    4
# Week                                                     1
# Hour                                                    15
# CONTRIBUTING_FACTOR_1                 unsafe lane changing
#
#                                                     4
# VEHICLE_TYPE                                    sedan
# VEHICLE_OCCUPANTS                                   2
# DRIVER_SEX                                          M
# PRE_CRASH                        going straight ahead
# POINT_OF_IMPACT                      center front end
# how_old                                            13
# MAKE                                             toyt
# Year                                             2019
# Month                                              10
# Week                                                4
# Hour                                               10
# CONTRIBUTING_FACTOR_1  driver inattention/distraction

# %%
dataset_trim = dataset.loc[dataset['CONTRIBUTING_FACTOR_1'].isin(dataset['CONTRIBUTING_FACTOR_1'].value_counts().index[dataset['CONTRIBUTING_FACTOR_1'].value_counts() > 40000])]

# %% [markdown]
# ### Spliting the dataset

# %%
X_training, X_test, y_training, y_test = train_test_split(dataset_trim.iloc[:,:-1], dataset_trim.iloc[:,-1],
                                                          test_size=0.05,
                                                          random_state = 42)

# %% [markdown]
# ### Constructing a pipeline.

# %%
cat_columns = ['VEHICLE_TYPE','DRIVER_SEX','POINT_OF_IMPACT','MAKE','Month','Week','Hour']
num_columns = ['how_old']

num_pipeline = Pipeline([('standardize_num', StandardScaler()),
                        ])

cat_pipeline = Pipeline([('create_dummies_cats', OneHotEncoder(drop='first',handle_unknown='ignore'))
                         ])

processing_pipeline = ColumnTransformer(transformers=[('proc_numeric', num_pipeline, num_columns),
                                                      ('create_dummies', cat_pipeline, cat_columns)])

processing_pipeline
# Out:
# ColumnTransformer(transformers=[('proc_numeric',
#                                  Pipeline(steps=[('standardize_num',
#                                                   StandardScaler())]),
#                                  ['how_old']),
#                                 ('create_dummies',
#                                  Pipeline(steps=[('create_dummies_cats',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'))]),
#                                  ['VEHICLE_TYPE', 'DRIVER_SEX',
#                                   'POINT_OF_IMPACT', 'MAKE', 'Month', 'Week',
#                                   'Hour'])])

# %% [markdown]
# ### Modeling

# %%
clf1 = LogisticRegression(max_iter=5000)
clf2 = DecisionTreeClassifier()
clf3 = RandomForestClassifier()

pipe1 = Pipeline([('data_processing', processing_pipeline),('logreg', clf1)])
pipe2 = Pipeline([('data_processing', processing_pipeline),('tree', clf2)])
pipe3 = Pipeline([('data_processing', processing_pipeline),('rf', clf3)])

# %% [markdown]
# ### Logistic regression

# %%
param_grid_lr= [
  {'logreg__class_weight': ['balanced'], 'logreg__C':[ 0.005, 0.01, 0.05, 0.1, 0.5 ],'logreg__solver':['saga','sag']}
 ]
gcv_lr = GridSearchCV(estimator=pipe1, param_grid=param_grid_lr, scoring=['accuracy'], cv=5, refit='accuracy',verbose=5)
gcv_lr = gcv_lr.fit(X_training, y_training)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END logreg__C=0.005, logreg__class_weight=balanced, logreg__solver=saga; accuracy: (test=0.260) total time=   5.3s
# [CV 2/5] END logreg__C=0.005, logreg__class_weight=balanced, logreg__solver=saga; accuracy: (test=0.260) total time=   5.7s
# [CV 3/5] END logreg__C=0.005, logreg__class_weight=balanced, logreg__solver=saga; accuracy: (test=0.260) total time=   5.2s
# [CV 4/5] END logreg__C=0.005, logreg__class_weight=balanced, logreg__solver=saga; accuracy: (test=0.260) total time=   5.6s
# [CV 5/5] END logreg__C=0.005, logreg__class_weight=balanced, logreg__solver=saga; accuracy: (test=0.260) total time=   5.1s
# [CV 1/5] END logreg__C=0.005, logreg__class_weight=balanced, logreg__solver=sag; accuracy: (test=0.260) total time=   4.3s
# [CV 2/5] END logreg__C=0.005, logreg__class_weight=balanced, logreg__solver=sag; accuracy: (test=0.260) total time=   4.3s
# [CV 3/5] END logreg__C=0.005, logreg__class_weight=balanced, logreg__solver=sag; accuracy: (test=0.260) total time=   4.0s
# [CV 4/5] END logreg__C=0.005, logreg__class_weight=balanced, logreg__solver=sag; accuracy: (test=0.260) total time=   4.6s
# [CV 5/5] END logreg__C=0.005, logreg__class_weight=balanced, logreg__solver=sag; accuracy: (test=0.260) total time=   5.1s
# [CV 1/5] END logreg__C=0.01, logreg__class_weight=balanced, logreg__solver=saga; accuracy: (test=0.260) total time=   5.7s
# [CV 2/5] END logreg__C=0.01, logreg__class_weight=balanced, logreg__solver=saga; accuracy: (test=0.260) total time=   5.6s
# [CV 3/5] END logreg__C=0.01, logreg__class_weight=balanced, logreg__solver=saga; accuracy: (test=0.260) total time=   5.8s
# [CV 4/5] END logreg__C=0.01, logreg__class_weight=balanced, logreg__solver=saga; accuracy: (test=0.260) total time=   5.8s
# [CV 5/5] END logreg__C=0.01, logreg__class_weight=balanced, logreg__solver=saga; accuracy: (test=0.260) total time=   5.9s
# [CV 1/5] END logreg__C=0.01, logreg__class_weight=balanced, logreg__solver=sag; accuracy: (test=0.260) total time=   4.6s
# [CV 2/5] END logreg__C=0.01, logreg__class_weight=balanced, logreg__solver=sag; accuracy: (test=0.260) total time=   4.7s
# [CV 3/5] END logreg__C=0.01, logreg__class_weight=balanced, logreg__solver=sag; accuracy: (test=0.260) total time=   5.1s
# [CV 4/5] END logreg__C=0.01, logreg__class_weight=balanced, logreg__solver=sag; accuracy: (test=0.260) total time=   4.7s
# [CV 5/5] END logreg__C=0.01, logreg__class_weight=balanced, logreg__solver=sag; accuracy: (test=0.260) total time=   4.6s
# [CV 1/5] END logreg__C=0.05, logreg__class_weight=balanced, logreg__solver=saga; accuracy: (test=0.258) total time=  17.4s
# [CV 2/5] END logreg__C=0.05, logreg__class_weight=balanced, logreg__solver=saga; accuracy: (test=0.259) total time=  16.6s
# [CV 3/5] END logreg__C=0.05, logreg__class_weight=balanced, logreg__solver=saga; accuracy: (test=0.259) total time=  18.6s
# [CV 4/5] END logreg__C=0.05, logreg__class_weight=balanced, logreg__solver=saga; accuracy: (test=0.258) total time=  17.8s
# [CV 5/5] END logreg__C=0.05, logreg__class_weight=balanced, logreg__solver=saga; accuracy: (test=0.258) total time=  15.9s
# [CV 1/5] END logreg__C=0.05, logreg__class_weight=balanced, logreg__solver=sag; accuracy: (test=0.258) total time=   5.2s
# [CV 2/5] END logreg__C=0.05, logreg__class_weight=balanced, logreg__solver=sag; accuracy: (test=0.259) total time=   5.3s
# [CV 3/5] END logreg__C=0.05, logreg__class_weight=balanced, logreg__solver=sag; accuracy: (test=0.259) total time=   5.3s
# [CV 4/5] END logreg__C=0.05, logreg__class_weight=balanced, logreg__solver=sag; accuracy: (test=0.258) total time=   4.9s
# [CV 5/5] END logreg__C=0.05, logreg__class_weight=balanced, logreg__solver=sag; accuracy: (test=0.258) total time=   5.0s
# [CV 1/5] END logreg__C=0.1, logreg__class_weight=balanced, logreg__solver=saga; accuracy: (test=0.258) total time=  24.1s
# [CV 2/5] END logreg__C=0.1, logreg__class_weight=balanced, logreg__solver=saga; accuracy: (test=0.258) total time=  24.0s
# [CV 3/5] END logreg__C=0.1, logreg__class_weight=balanced, logreg__solver=saga; accuracy: (test=0.258) total time=  23.8s
# [CV 4/5] END logreg__C=0.1, logreg__class_weight=balanced, logreg__solver=saga; accuracy: (test=0.258) total time=  20.5s
# [CV 5/5] END logreg__C=0.1, logreg__class_weight=balanced, logreg__solver=saga; accuracy: (test=0.258) total time=  23.7s
# [CV 1/5] END logreg__C=0.1, logreg__class_weight=balanced, logreg__solver=sag; accuracy: (test=0.258) total time=   5.6s
# [CV 2/5] END logreg__C=0.1, logreg__class_weight=balanced, logreg__solver=sag; accuracy: (test=0.258) total time=   6.1s
# [CV 3/5] END logreg__C=0.1, logreg__class_weight=balanced, logreg__solver=sag; accuracy: (test=0.258) total time=   5.5s
# [CV 4/5] END logreg__C=0.1, logreg__class_weight=balanced, logreg__solver=sag; accuracy: (test=0.258) total time=   5.5s
# [CV 5/5] END logreg__C=0.1, logreg__class_weight=balanced, logreg__solver=sag; accuracy: (test=0.258) total time=   5.4s
# [CV 1/5] END logreg__C=0.5, logreg__class_weight=balanced, logreg__solver=saga; accuracy: (test=0.258) total time=  29.9s
# [CV 2/5] END logreg__C=0.5, logreg__class_weight=balanced, logreg__solver=saga; accuracy: (test=0.258) total time=  28.1s
# [CV 3/5] END logreg__C=0.5, logreg__class_weight=balanced, logreg__solver=saga; accuracy: (test=0.258) total time=  27.0s
# [CV 4/5] END logreg__C=0.5, logreg__class_weight=balanced, logreg__solver=saga; accuracy: (test=0.258) total time=  26.5s
# [CV 5/5] END logreg__C=0.5, logreg__class_weight=balanced, logreg__solver=saga; accuracy: (test=0.258) total time=  29.6s
# [CV 1/5] END logreg__C=0.5, logreg__class_weight=balanced, logreg__solver=sag; accuracy: (test=0.258) total time=   8.4s
# [CV 2/5] END logreg__C=0.5, logreg__class_weight=balanced, logreg__solver=sag; accuracy: (test=0.258) total time=   8.1s
# [CV 3/5] END logreg__C=0.5, logreg__class_weight=balanced, logreg__solver=sag; accuracy: (test=0.258) total time=   8.3s
# [CV 4/5] END logreg__C=0.5, logreg__class_weight=balanced, logreg__solver=sag; accuracy: (test=0.258) total time=   8.7s
# [CV 5/5] END logreg__C=0.5, logreg__class_weight=balanced, logreg__solver=sag; accuracy: (test=0.258) total time=   8.1s

# %%
gcv_lr.best_estimator_
# Out:
# Pipeline(steps=[('data_processing',
#                  ColumnTransformer(transformers=[('proc_numeric',
#                                                   Pipeline(steps=[('standardize_num',
#                                                                    StandardScaler())]),
#                                                   ['how_old']),
#                                                  ('create_dummies',
#                                                   Pipeline(steps=[('create_dummies_cats',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore'))]),
#                                                   ['VEHICLE_TYPE', 'DRIVER_SEX',
#                                                    'POINT_OF_IMPACT', 'MAKE',
#                                                    'Month', 'Week',
#                                                    'Hour'])])),
#                 ('logreg',
#                  LogisticRegression(C=0.005, class_weight='balanced',
#                                     max_iter=5000, solver='saga'))])

# %%
ypred_lr = gcv_lr.predict(X_test)
print(classification_report(y_test, ypred_lr, digits=3))
# Out:
#                                 precision    recall  f1-score   support
#
# driver inattention/distraction      0.601     0.031     0.058     12589
#  failure to yield right-of-way      0.210     0.370     0.268      3444
#          following too closely      0.425     0.627     0.506      4853
#                          other      0.167     0.258     0.203      1986
# passing or lane usage improper      0.157     0.615     0.251      2047
#
#                       accuracy                          0.260     24919
#                      macro avg      0.312     0.380     0.257     24919
#                   weighted avg      0.442     0.260     0.202     24919

# %%
confusion_matrix(y_test, ypred_lr)
# Out:
# array([[ 387, 3002, 3009, 1603, 4588],
#        [  50, 1273,  568,  295, 1258],
#        [ 101,  876, 3041,  443,  392],
#        [  57,  434,  480,  513,  502],
#        [  49,  464,   64,  211, 1259]], dtype=int64)

# %% [markdown]
# ### Observations
# - When we use a logistic regression to classify the contributing factor we get a macro average of 0.312
# - When it comes to driver's inattention the model has a 60% precision.
# - When it comes to failure to yield right-of-way the model has a 21% precision.
# - When it comes to following too closely the model has a 42.5% precision.
# - When it comes to improper lane usage the model has a 15.7% precision.
# - For others the model has a 16.7% precision.

# %% [markdown]
# ### Decision tree

# %%
param_grid_tree = [
  {'tree__max_depth': [10, 25, 50],
   'tree__min_samples_split':[10, 25, 50, 100],
   'tree__min_samples_leaf': [50,100],
   'tree__class_weight':['balanced']
  }
 ]

gcv_tree = GridSearchCV(estimator=pipe2, param_grid=param_grid_tree, scoring='accuracy', refit=True, verbose=10)
gcv_tree = gcv_tree.fit(X_training, y_training)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5; 1/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=10
# [CV 1/5; 1/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=10;, score=0.248 total time=   2.6s
# [CV 2/5; 1/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=10
# [CV 2/5; 1/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=10;, score=0.250 total time=   2.6s
# [CV 3/5; 1/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=10
# [CV 3/5; 1/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=10;, score=0.250 total time=   2.7s
# [CV 4/5; 1/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=10
# [CV 4/5; 1/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=10;, score=0.246 total time=   2.7s
# [CV 5/5; 1/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=10
# [CV 5/5; 1/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=10;, score=0.252 total time=   2.7s
# [CV 1/5; 2/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=25
# [CV 1/5; 2/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=25;, score=0.248 total time=   2.7s
# [CV 2/5; 2/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=25
# [CV 2/5; 2/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=25;, score=0.250 total time=   2.6s
# [CV 3/5; 2/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=25
# [CV 3/5; 2/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=25;, score=0.250 total time=   2.6s
# [CV 4/5; 2/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=25
# [CV 4/5; 2/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=25;, score=0.246 total time=   2.7s
# [CV 5/5; 2/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=25
# [CV 5/5; 2/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=25;, score=0.252 total time=   2.7s
# [CV 1/5; 3/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=50
# [CV 1/5; 3/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=50;, score=0.248 total time=   2.7s
# [CV 2/5; 3/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=50
# [CV 2/5; 3/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=50;, score=0.250 total time=   2.7s
# [CV 3/5; 3/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=50
# [CV 3/5; 3/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=50;, score=0.250 total time=   2.6s
# [CV 4/5; 3/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=50
# [CV 4/5; 3/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=50;, score=0.246 total time=   2.6s
# [CV 5/5; 3/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=50
# [CV 5/5; 3/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=50;, score=0.252 total time=   2.6s
# [CV 1/5; 4/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=100
# [CV 1/5; 4/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=100;, score=0.248 total time=   2.7s
# [CV 2/5; 4/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=100
# [CV 2/5; 4/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=100;, score=0.250 total time=   2.7s
# [CV 3/5; 4/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=100
# [CV 3/5; 4/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=100;, score=0.250 total time=   2.6s
# [CV 4/5; 4/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=100
# [CV 4/5; 4/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=100;, score=0.246 total time=   2.7s
# [CV 5/5; 4/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=100
# [CV 5/5; 4/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=50, tree__min_samples_split=100;, score=0.252 total time=   2.8s
# [CV 1/5; 5/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=10
# [CV 1/5; 5/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=10;, score=0.246 total time=   2.6s
# [CV 2/5; 5/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=10
# [CV 2/5; 5/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=10;, score=0.250 total time=   2.6s
# [CV 3/5; 5/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=10
# [CV 3/5; 5/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=10;, score=0.249 total time=   2.5s
# [CV 4/5; 5/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=10
# [CV 4/5; 5/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=10;, score=0.246 total time=   2.7s
# [CV 5/5; 5/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=10
# [CV 5/5; 5/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=10;, score=0.251 total time=   2.7s
# [CV 1/5; 6/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=25
# [CV 1/5; 6/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=25;, score=0.246 total time=   2.6s
# [CV 2/5; 6/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=25
# [CV 2/5; 6/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=25;, score=0.250 total time=   2.6s
# [CV 3/5; 6/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=25
# [CV 3/5; 6/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=25;, score=0.249 total time=   2.6s
# [CV 4/5; 6/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=25
# [CV 4/5; 6/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=25;, score=0.246 total time=   2.7s
# [CV 5/5; 6/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=25
# [CV 5/5; 6/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=25;, score=0.251 total time=   2.6s
# [CV 1/5; 7/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=50
# [CV 1/5; 7/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=50;, score=0.246 total time=   2.7s
# [CV 2/5; 7/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=50
# [CV 2/5; 7/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=50;, score=0.250 total time=   2.7s
# [CV 3/5; 7/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=50
# [CV 3/5; 7/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=50;, score=0.249 total time=   2.6s
# [CV 4/5; 7/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=50
# [CV 4/5; 7/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=50;, score=0.246 total time=   2.7s
# [CV 5/5; 7/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=50
# [CV 5/5; 7/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=50;, score=0.251 total time=   2.7s
# [CV 1/5; 8/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=100
# [CV 1/5; 8/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=100;, score=0.246 total time=   2.8s
# [CV 2/5; 8/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=100
# [CV 2/5; 8/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=100;, score=0.250 total time=   2.9s
# [CV 3/5; 8/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=100
# [CV 3/5; 8/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=100;, score=0.249 total time=   2.6s
# [CV 4/5; 8/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=100
# [CV 4/5; 8/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=100;, score=0.246 total time=   2.6s
# [CV 5/5; 8/24] START tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=100
# [CV 5/5; 8/24] END tree__class_weight=balanced, tree__max_depth=10, tree__min_samples_leaf=100, tree__min_samples_split=100;, score=0.251 total time=   2.7s
# [CV 1/5; 9/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=10
# [CV 1/5; 9/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=10;, score=0.255 total time=  13.5s
# [CV 2/5; 9/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=10
# [CV 2/5; 9/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=10;, score=0.254 total time=  13.1s
# [CV 3/5; 9/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=10
# [CV 3/5; 9/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=10;, score=0.259 total time=  13.1s
# [CV 4/5; 9/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=10
# [CV 4/5; 9/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=10;, score=0.257 total time=  14.0s
# [CV 5/5; 9/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=10
# [CV 5/5; 9/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=10;, score=0.257 total time=  13.5s
# [CV 1/5; 10/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=25
# [CV 1/5; 10/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=25;, score=0.255 total time=  14.2s
# [CV 2/5; 10/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=25
# [CV 2/5; 10/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=25;, score=0.254 total time=  13.4s
# [CV 3/5; 10/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=25
# [CV 3/5; 10/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=25;, score=0.259 total time=  13.1s
# [CV 4/5; 10/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=25
# [CV 4/5; 10/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=25;, score=0.257 total time=  13.7s
# [CV 5/5; 10/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=25
# [CV 5/5; 10/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=25;, score=0.257 total time=  13.3s
# [CV 1/5; 11/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=50
# [CV 1/5; 11/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=50;, score=0.255 total time=  14.2s
# [CV 2/5; 11/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=50
# [CV 2/5; 11/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=50;, score=0.254 total time=  13.7s
# [CV 3/5; 11/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=50
# [CV 3/5; 11/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=50;, score=0.259 total time=  13.4s
# [CV 4/5; 11/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=50
# [CV 4/5; 11/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=50;, score=0.257 total time=  13.9s
# [CV 5/5; 11/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=50
# [CV 5/5; 11/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=50;, score=0.257 total time=  13.4s
# [CV 1/5; 12/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=100
# [CV 1/5; 12/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=100;, score=0.255 total time=  14.1s
# [CV 2/5; 12/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=100
# [CV 2/5; 12/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=100;, score=0.254 total time=  13.3s
# [CV 3/5; 12/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=100
# [CV 3/5; 12/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=100;, score=0.259 total time=  13.1s
# [CV 4/5; 12/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=100
# [CV 4/5; 12/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=100;, score=0.257 total time=  14.2s
# [CV 5/5; 12/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=100
# [CV 5/5; 12/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=50, tree__min_samples_split=100;, score=0.257 total time=  13.8s
# [CV 1/5; 13/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=10
# [CV 1/5; 13/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=10;, score=0.257 total time=  12.0s
# [CV 2/5; 13/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=10
# [CV 2/5; 13/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=10;, score=0.256 total time=  11.7s
# [CV 3/5; 13/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=10
# [CV 3/5; 13/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=10;, score=0.257 total time=  11.4s
# [CV 4/5; 13/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=10
# [CV 4/5; 13/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=10;, score=0.258 total time=  11.5s
# [CV 5/5; 13/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=10
# [CV 5/5; 13/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=10;, score=0.257 total time=  11.0s
# [CV 1/5; 14/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=25
# [CV 1/5; 14/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=25;, score=0.257 total time=  12.1s
# [CV 2/5; 14/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=25
# [CV 2/5; 14/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=25;, score=0.256 total time=  11.7s
# [CV 3/5; 14/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=25
# [CV 3/5; 14/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=25;, score=0.257 total time=  11.6s
# [CV 4/5; 14/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=25
# [CV 4/5; 14/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=25;, score=0.258 total time=  12.0s
# [CV 5/5; 14/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=25
# [CV 5/5; 14/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=25;, score=0.257 total time=  11.2s
# [CV 1/5; 15/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=50
# [CV 1/5; 15/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=50;, score=0.257 total time=  11.6s
# [CV 2/5; 15/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=50
# [CV 2/5; 15/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=50;, score=0.256 total time=  11.7s
# [CV 3/5; 15/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=50
# [CV 3/5; 15/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=50;, score=0.257 total time=  11.6s
# [CV 4/5; 15/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=50
# [CV 4/5; 15/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=50;, score=0.258 total time=  11.5s
# [CV 5/5; 15/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=50
# [CV 5/5; 15/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=50;, score=0.257 total time=  11.0s
# [CV 1/5; 16/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=100
# [CV 1/5; 16/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=100;, score=0.257 total time=  11.6s
# [CV 2/5; 16/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=100
# [CV 2/5; 16/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=100;, score=0.256 total time=  11.6s
# [CV 3/5; 16/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=100
# [CV 3/5; 16/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=100;, score=0.257 total time=  11.4s
# [CV 4/5; 16/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=100
# [CV 4/5; 16/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=100;, score=0.258 total time=  11.8s
# [CV 5/5; 16/24] START tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=100
# [CV 5/5; 16/24] END tree__class_weight=balanced, tree__max_depth=25, tree__min_samples_leaf=100, tree__min_samples_split=100;, score=0.257 total time=  11.8s
# [CV 1/5; 17/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=10
# [CV 1/5; 17/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=10;, score=0.259 total time=  18.8s
# [CV 2/5; 17/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=10
# [CV 2/5; 17/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=10;, score=0.256 total time=  18.4s
# [CV 3/5; 17/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=10
# [CV 3/5; 17/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=10;, score=0.259 total time=  18.6s
# [CV 4/5; 17/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=10
# [CV 4/5; 17/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=10;, score=0.259 total time=  18.1s
# [CV 5/5; 17/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=10
# [CV 5/5; 17/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=10;, score=0.261 total time=  18.7s
# [CV 1/5; 18/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=25
# [CV 1/5; 18/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=25;, score=0.259 total time=  18.6s
# [CV 2/5; 18/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=25
# [CV 2/5; 18/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=25;, score=0.256 total time=  18.2s
# [CV 3/5; 18/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=25
# [CV 3/5; 18/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=25;, score=0.259 total time=  18.3s
# [CV 4/5; 18/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=25
# [CV 4/5; 18/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=25;, score=0.259 total time=  18.3s
# [CV 5/5; 18/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=25
# [CV 5/5; 18/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=25;, score=0.261 total time=  18.4s
# [CV 1/5; 19/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=50
# [CV 1/5; 19/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=50;, score=0.259 total time=  18.4s
# [CV 2/5; 19/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=50
# [CV 2/5; 19/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=50;, score=0.256 total time=  18.6s
# [CV 3/5; 19/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=50
# [CV 3/5; 19/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=50;, score=0.259 total time=  18.2s
# [CV 4/5; 19/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=50
# [CV 4/5; 19/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=50;, score=0.259 total time=  18.8s
# [CV 5/5; 19/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=50
# [CV 5/5; 19/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=50;, score=0.261 total time=  18.8s
# [CV 1/5; 20/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=100
# [CV 1/5; 20/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=100;, score=0.259 total time=  18.5s
# [CV 2/5; 20/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=100
# [CV 2/5; 20/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=100;, score=0.256 total time=  18.8s
# [CV 3/5; 20/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=100
# [CV 3/5; 20/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=100;, score=0.259 total time=  18.2s
# [CV 4/5; 20/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=100
# [CV 4/5; 20/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=100;, score=0.259 total time=  18.9s
# [CV 5/5; 20/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=100
# [CV 5/5; 20/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=50, tree__min_samples_split=100;, score=0.261 total time=  17.9s
# [CV 1/5; 21/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=10
# [CV 1/5; 21/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=10;, score=0.258 total time=  13.2s
# [CV 2/5; 21/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=10
# [CV 2/5; 21/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=10;, score=0.257 total time=  13.1s
# [CV 3/5; 21/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=10
# [CV 3/5; 21/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=10;, score=0.259 total time=  13.1s
# [CV 4/5; 21/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=10
# [CV 4/5; 21/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=10;, score=0.260 total time=  13.0s
# [CV 5/5; 21/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=10
# [CV 5/5; 21/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=10;, score=0.258 total time=  13.2s
# [CV 1/5; 22/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=25
# [CV 1/5; 22/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=25;, score=0.258 total time=  13.1s
# [CV 2/5; 22/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=25
# [CV 2/5; 22/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=25;, score=0.257 total time=  13.0s
# [CV 3/5; 22/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=25
# [CV 3/5; 22/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=25;, score=0.259 total time=  13.1s
# [CV 4/5; 22/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=25
# [CV 4/5; 22/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=25;, score=0.260 total time=  13.5s
# [CV 5/5; 22/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=25
# [CV 5/5; 22/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=25;, score=0.258 total time=  13.6s
# [CV 1/5; 23/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=50
# [CV 1/5; 23/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=50;, score=0.258 total time=  13.2s
# [CV 2/5; 23/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=50
# [CV 2/5; 23/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=50;, score=0.257 total time=  13.2s
# [CV 3/5; 23/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=50
# [CV 3/5; 23/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=50;, score=0.259 total time=  13.9s
# [CV 4/5; 23/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=50
# [CV 4/5; 23/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=50;, score=0.260 total time=  13.8s
# [CV 5/5; 23/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=50
# [CV 5/5; 23/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=50;, score=0.258 total time=  13.9s
# [CV 1/5; 24/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=100
# [CV 1/5; 24/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=100;, score=0.258 total time=  13.9s
# [CV 2/5; 24/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=100
# [CV 2/5; 24/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=100;, score=0.257 total time=  13.2s
# [CV 3/5; 24/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=100
# [CV 3/5; 24/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=100;, score=0.259 total time=  13.3s
# [CV 4/5; 24/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=100
# [CV 4/5; 24/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=100;, score=0.260 total time=  13.8s
# [CV 5/5; 24/24] START tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=100
# [CV 5/5; 24/24] END tree__class_weight=balanced, tree__max_depth=50, tree__min_samples_leaf=100, tree__min_samples_split=100;, score=0.258 total time=  13.6s

# %%
gcv_tree.best_estimator_
# Out:
# Pipeline(steps=[('data_processing',
#                  ColumnTransformer(transformers=[('proc_numeric',
#                                                   Pipeline(steps=[('standardize_num',
#                                                                    StandardScaler())]),
#                                                   ['how_old']),
#                                                  ('create_dummies',
#                                                   Pipeline(steps=[('create_dummies_cats',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore'))]),
#                                                   ['VEHICLE_TYPE', 'DRIVER_SEX',
#                                                    'POINT_OF_IMPACT', 'MAKE',
#                                                    'Month', 'Week',
#                                                    'Hour'])])),
#                 ('tree',
#                  DecisionTreeClassifier(class_weight='balanced', max_depth=50,
#                                         min_samples_leaf=50,
#                                         min_samples_split=10))])

# %%
ypred_tree = gcv_tree.predict(X_test)
print(classification_report(y_test, ypred_tree, digits=3))
# Out:
#                                 precision    recall  f1-score   support
#
# driver inattention/distraction      0.563     0.057     0.104     12589
#  failure to yield right-of-way      0.211     0.317     0.254      3444
#          following too closely      0.411     0.615     0.493      4853
#                          other      0.138     0.300     0.189      1986
# passing or lane usage improper      0.151     0.509     0.233      2047
#
#                       accuracy                          0.258     24919
#                      macro avg      0.295     0.360     0.255     24919
#                   weighted avg      0.417     0.258     0.218     24919

# %%
confusion_matrix(y_test, ypred_tree)
# Out:
# array([[ 720, 2599, 3101, 2241, 3928],
#        [ 191, 1093,  584,  520, 1056],
#        [ 158,  605, 2987,  639,  464],
#        [  86,  390,  509,  596,  405],
#        [ 123,  484,   80,  318, 1042]], dtype=int64)

# %% [markdown]
# ### Observations
# - When we use a decision tree to classify the contributing factor we get a macro average of 0.295
# - When it comes to driver's inattention the model has a 56% precision.
# - When it comes to failure to yield right-of-way the model has a 21% precision.
# - When it comes to following too closely the model has a 42% precision.
# - When it comes to improper lane usage the model has a 15% precision.
# - For others the model has a 13.8% precision.

# %% [markdown]
# ### Random Forest

# %%
param_grid_rf = [{'rf__max_depth': [5, 10, 15],
               'rf__n_estimators': [10, 50, 100],
               'rf__class_weight': ['balanced', 'balanced_subsample'],
               'rf__max_samples': [1000, 2000, 5000]
              }]

gcv_rf = GridSearchCV(estimator=pipe3, param_grid=param_grid_rf, scoring='accuracy', refit=True, verbose=10)
gcv_rf = gcv_rf.fit(X_training, y_training)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV 1/5; 1/54] START rf__class_weight=balanced, rf__max_depth=5, rf__max_samples=1000, rf__n_estimators=10
# [CV 1/5; 1/54] END rf__class_weight=balanced, rf__max_depth=5, rf__max_samples=1000, rf__n_estimators=10;, score=0.255 total time=   1.5s
# [CV 2/5; 1/54] START rf__class_weight=balanced, rf__max_depth=5, rf__max_samples=1000, rf__n_estimators=10
# [CV 2/5; 1/54] END rf__class_weight=balanced, rf__max_depth=5, rf__max_samples=1000, rf__n_estimators=10;, score=0.264 total time=   1.5s
# [CV 3/5; 1/54] START rf__class_weight=balanced, rf__max_depth=5, rf__max_samples=1000, rf__n_estimators=10
# [CV 3/5; 1/54] END rf__class_weight=balanced, rf__max_depth=5, rf__max_samples=1000, rf__n_estimators=10;, score=0.258 total time=   1.5s
# [CV 4/5; 1/54] START rf__class_weight=balanced, rf__max_depth=5, rf__max_samples=1000, rf__n_estimators=10
# [CV 4/5; 1/54] END rf__class_weight=balanced, rf__max_depth=5, rf__max_samples=1000, rf__n_estimators=10;, score=0.253 total time=   1.5s
# [CV 5/5; 1/54] START rf__class_weight=balanced, rf__max_depth=5, rf__max_samples=1000, rf__n_estimators=10
# [CV 5/5; 1/54] END rf__class_weight=balanced, rf__max_depth=5, rf__max_samples=1000, rf__n_estimators=10;, score=0.251 total time=   1.5s
# [CV 1/5; 2/54] START rf__class_weight=balanced, rf__max_depth=5, rf__max_samples=1000, rf__n_estimators=50
# [CV 1/5; 2/54] END rf__class_weight=balanced, rf__max_depth=5, rf__max_samples=1000, rf__n_estimators=50;, score=0.261 total time=   3.0s
# [CV 2/5; 2/54] START rf__class_weight=balanced, rf__max_depth=5, rf__max_samples=1000, rf__n_estimators=50
# [CV 2/5; 2/54] END rf__class_weight=balanced, rf__max_depth=5, rf__max_samples=1000, rf__n_estimators=50;, score=0
5; 45/54] START rf__class_weight=balanced_subsample, rf__max_depth=10, rf__max_samples=5000, rf__n_estimators=100
# [CV 2/5; 45/54] END rf__class_weight=balanced_subsample, rf__max_depth=10, rf__max_samples=5000, rf__n_estimators=100;, score=0.279 total time=   8.3s
# [CV 3/5; 45/54] START rf__class_weight=balanced_subsample, rf__max_depth=10, rf__max_samples=5000, rf__n_estimators=100
# [CV 3/5; 45/54] END rf__class_weight=balanced_subsample, rf__max_depth=10, rf__max_samples=5000, rf__n_estimators=100;, score=0.276 total time=   8.2s
# [CV 4/5; 45/54] START rf__class_weight=balanced_subsample, rf__max_depth=10, rf__max_samples=5000, rf__n_estimators=100
# [CV 4/5; 45/54] END rf__class_weight=balanced_subsample, rf__max_depth=10, rf__max_samples=5000, rf__n_estimators=100;, score=0.276 total time=   8.5s
# [CV 5/5; 45/54] START rf__class_weight=balanced_subsample, rf__max_depth=10, rf__max_samples=5000, rf__n_estimators=100
# [CV 5/5; 45/54] END rf__class_weight=balanced_subsample, rf__max_depth=10, rf__max_samples=5000, rf__n_estimators=100;, score=0.279 total time=   8.4s
# [CV 1/5; 46/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=10
# [CV 1/5; 46/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=10;, score=0.399 total time=   1.7s
# [CV 2/5; 46/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=10
# [CV 2/5; 46/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=10;, score=0.400 total time=   1.7s
# [CV 3/5; 46/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=10
# [CV 3/5; 46/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=10;, score=0.394 total time=   1.7s
# [CV 4/5; 46/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=10
# [CV 4/5; 46/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=10;, score=0.400 total time=   1.7s
# [CV 5/5; 46/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=10
# [CV 5/5; 46/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=10;, score=0.401 total time=   1.7s
# [CV 1/5; 47/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=50
# [CV 1/5; 47/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=50;, score=0.471 total time=   4.9s
# [CV 2/5; 47/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=50
# [CV 2/5; 47/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=50;, score=0.469 total time=   4.9s
# [CV 3/5; 47/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=50
# [CV 3/5; 47/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=50;, score=0.473 total time=   4.8s
# [CV 4/5; 47/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=50
# [CV 4/5; 47/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=50;, score=0.463 total time=   4.8s
# [CV 5/5; 47/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=50
# [CV 5/5; 47/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=50;, score=0.473 total time=   4.6s
# [CV 1/5; 48/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=100
# [CV 1/5; 48/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=100;, score=0.484 total time=   8.3s
# [CV 2/5; 48/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=100
# [CV 2/5; 48/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=100;, score=0.487 total time=   8.4s
# [CV 3/5; 48/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=100
# [CV 3/5; 48/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=100;, score=0.483 total time=   8.4s
# [CV 4/5; 48/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=100
# [CV 4/5; 48/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=100;, score=0.480 total time=   8.5s
# [CV 5/5; 48/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=100
# [CV 5/5; 48/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=1000, rf__n_estimators=100;, score=0.488 total time=   8.4s
# [CV 1/5; 49/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=10
# [CV 1/5; 49/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=10;, score=0.369 total time=   1.8s
# [CV 2/5; 49/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=10
# [CV 2/5; 49/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=10;, score=0.372 total time=   1.8s
# [CV 3/5; 49/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=10
# [CV 3/5; 49/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=10;, score=0.383 total time=   1.8s
# [CV 4/5; 49/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=10
# [CV 4/5; 49/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=10;, score=0.374 total time=   1.7s
# [CV 5/5; 49/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=10
# [CV 5/5; 49/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=10;, score=0.375 total time=   1.7s
# [CV 1/5; 50/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=50
# [CV 1/5; 50/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=50;, score=0.430 total time=   5.2s
# [CV 2/5; 50/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=50
# [CV 2/5; 50/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=50;, score=0.434 total time=   5.2s
# [CV 3/5; 50/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=50
# [CV 3/5; 50/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=50;, score=0.428 total time=   5.3s
# [CV 4/5; 50/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=50
# [CV 4/5; 50/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=50;, score=0.436 total time=   5.2s
# [CV 5/5; 50/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=50
# [CV 5/5; 50/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=50;, score=0.426 total time=   5.3s
# [CV 1/5; 51/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=100
# [CV 1/5; 51/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=100;, score=0.450 total time=   9.7s
# [CV 2/5; 51/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=100
# [CV 2/5; 51/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=100;, score=0.450 total time=   9.6s
# [CV 3/5; 51/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=100
# [CV 3/5; 51/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=100;, score=0.446 total time=   9.6s
# [CV 4/5; 51/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=100
# [CV 4/5; 51/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=100;, score=0.448 total time=   9.7s
# [CV 5/5; 51/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=100
# [CV 5/5; 51/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=2000, rf__n_estimators=100;, score=0.452 total time=   9.6s
# [CV 1/5; 52/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=10
# [CV 1/5; 52/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=10;, score=0.341 total time=   2.0s
# [CV 2/5; 52/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=10
# [CV 2/5; 52/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=10;, score=0.344 total time=   2.0s
# [CV 3/5; 52/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=10
# [CV 3/5; 52/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=10;, score=0.337 total time=   2.0s
# [CV 4/5; 52/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=10
# [CV 4/5; 52/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=10;, score=0.344 total time=   2.0s
# [CV 5/5; 52/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=10
# [CV 5/5; 52/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=10;, score=0.334 total time=   2.0s
# [CV 1/5; 53/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=50
# [CV 1/5; 53/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=50;, score=0.370 total time=   6.7s
# [CV 2/5; 53/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=50
# [CV 2/5; 53/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=50;, score=0.373 total time=   7.0s
# [CV 3/5; 53/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=50
# [CV 3/5; 53/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=50;, score=0.366 total time=   7.2s
# [CV 4/5; 53/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=50
# [CV 4/5; 53/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=50;, score=0.367 total time=   7.2s
# [CV 5/5; 53/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=50
# [CV 5/5; 53/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=50;, score=0.370 total time=   7.0s
# [CV 1/5; 54/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=100
# [CV 1/5; 54/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=100;, score=0.375 total time=  12.9s
# [CV 2/5; 54/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=100
# [CV 2/5; 54/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=100;, score=0.374 total time=  12.4s
# [CV 3/5; 54/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=100
# [CV 3/5; 54/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=100;, score=0.379 total time=  12.2s
# [CV 4/5; 54/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=100
# [CV 4/5; 54/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=100;, score=0.375 total time=  13.2s
# [CV 5/5; 54/54] START rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=100
# [CV 5/5; 54/54] END rf__class_weight=balanced_subsample, rf__max_depth=15, rf__max_samples=5000, rf__n_estimators=100;, score=0.374 total time=  13.2s

# %%
gcv_rf.best_estimator_
# Out:
# Pipeline(steps=[('data_processing',
#                  ColumnTransformer(transformers=[('proc_numeric',
#                                                   Pipeline(steps=[('standardize_num',
#                                                                    StandardScaler())]),
#                                                   ['how_old']),
#                                                  ('create_dummies',
#                                                   Pipeline(steps=[('create_dummies_cats',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore'))]),
#                                                   ['VEHICLE_TYPE', 'DRIVER_SEX',
#                                                    'POINT_OF_IMPACT', 'MAKE',
#                                                    'Month', 'Week',
#                                                    'Hour'])])),
#                 ('rf',
#                  RandomForestClassifier(class_weight='balanced', max_depth=15,
#                                         max_samples=1000))])

# %%
ypred_rf = gcv_rf.predict(X_test)
print(classification_report(y_test, ypred_rf, digits=3))
# Out:
#                                 precision    recall  f1-score   support
#
# driver inattention/distraction      0.542     0.705     0.613     12589
#  failure to yield right-of-way      0.210     0.048     0.078      3444
#          following too closely      0.419     0.643     0.507      4853
#                          other      0.311     0.016     0.031      1986
# passing or lane usage improper      0.166     0.018     0.033      2047
#
#                       accuracy                          0.490     24919
#                      macro avg      0.329     0.286     0.252     24919
#                   weighted avg      0.423     0.490     0.424     24919

# %%
confusion_matrix(y_test, ypred_rf)
# Out:
# array([[8870,  388, 3147,   52,  132],
#        [2665,  164,  578,    4,   33],
#        [1590,  125, 3119,    6,   13],
#        [1356,   47,  543,   32,    8],
#        [1880,   57,   64,    9,   37]], dtype=int64)

# %% [markdown]
# ### Observations
# - When we use a Random Forest to classify the contributing factor we get a macro average of 0.329
# - When it comes to driver's inattention the model has a 54% precision.
# - When it comes to failure to yield right-of-way the model has a 21% precision.
# - When it comes to following too closely the model has a 42% precision.
# - When it comes to improper lane usage the model has a 16.6% precision.
# - For others the model has a 31% precision.

# %% [markdown]
# ### Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
pipe5 = Pipeline([('processing', processing_pipeline),
             ('gb', GradientBoostingClassifier())])

params_gb = {'gb__max_depth': [1, 3],
         'gb__n_estimators': [10, 25]
         }

gcv_gb = GridSearchCV(pipe5, param_grid = params_gb, cv=2, scoring='accuracy', verbose=10)
gcv_gb = gcv_gb.fit(X_training, y_training)
# Out:
# Fitting 2 folds for each of 4 candidates, totalling 8 fits
# [CV 1/2; 1/4] START gb__max_depth=1, gb__n_estimators=10........................
# [CV 1/2; 1/4] END gb__max_depth=1, gb__n_estimators=10;, score=0.504 total time=   4.5s
# [CV 2/2; 1/4] START gb__max_depth=1, gb__n_estimators=10........................
# [CV 2/2; 1/4] END gb__max_depth=1, gb__n_estimators=10;, score=0.504 total time=   4.5s
# [CV 1/2; 2/4] START gb__max_depth=1, gb__n_estimators=25........................
# [CV 1/2; 2/4] END gb__max_depth=1, gb__n_estimators=25;, score=0.504 total time=  10.4s
# [CV 2/2; 2/4] START gb__max_depth=1, gb__n_estimators=25........................
# [CV 2/2; 2/4] END gb__max_depth=1, gb__n_estimators=25;, score=0.504 total time=  10.1s
# [CV 1/2; 3/4] START gb__max_depth=3, gb__n_estimators=10........................
# [CV 1/2; 3/4] END gb__max_depth=3, gb__n_estimators=10;, score=0.504 total time=   8.3s
# [CV 2/2; 3/4] START gb__max_depth=3, gb__n_estimators=10........................
# [CV 2/2; 3/4] END gb__max_depth=3, gb__n_estimators=10;, score=0.504 total time=   8.5s
# [CV 1/2; 4/4] START gb__max_depth=3, gb__n_estimators=25........................
# [CV 1/2; 4/4] END gb__max_depth=3, gb__n_estimators=25;, score=0.508 total time=  19.1s
# [CV 2/2; 4/4] START gb__max_depth=3, gb__n_estimators=25........................
# [CV 2/2; 4/4] END gb__max_depth=3, gb__n_estimators=25;, score=0.507 total time=  18.4s

# %%
gcv_gb.best_estimator_
# Out:
# Pipeline(steps=[('processing',
#                  ColumnTransformer(transformers=[('proc_numeric',
#                                                   Pipeline(steps=[('standardize_num',
#                                                                    StandardScaler())]),
#                                                   ['how_old']),
#                                                  ('create_dummies',
#                                                   Pipeline(steps=[('create_dummies_cats',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore'))]),
#                                                   ['VEHICLE_TYPE', 'DRIVER_SEX',
#                                                    'POINT_OF_IMPACT', 'MAKE',
#                                                    'Month', 'Week',
#                                                    'Hour'])])),
#                 ('gb', GradientBoostingClassifier(n_estimators=25))])

# %%
ypred_gb = gcv_gb.predict(X_test)
print(classification_report(y_test, ypred_gb, digits=3))
# Out:
#                                 precision    recall  f1-score   support
#
# driver inattention/distraction      0.511     0.966     0.668     12589
#  failure to yield right-of-way      0.000     0.000     0.000      3444
#          following too closely      0.454     0.104     0.169      4853
#                          other      0.333     0.001     0.001      1986
# passing or lane usage improper      0.000     0.000     0.000      2047
#
#                       accuracy                          0.508     24919
#                      macro avg      0.260     0.214     0.168     24919
#                   weighted avg      0.373     0.508     0.371     24919

# %%
confusion_matrix(y_test, ypred_gb)
# Out:
# array([[12157,     0,   430,     2,     0],
#        [ 3359,     0,    85,     0,     0],
#        [ 4349,     0,   504,     0,     0],
#        [ 1902,     0,    83,     1,     0],
#        [ 2039,     0,     8,     0,     0]], dtype=int64)

# %% [markdown]
# ### Observations
# - When we use a gradient boosting to classify the contributing factor we get a macro average of 0.260
# - When it comes to driver's inattention the model has a 51% precision.
# - When it comes to failure to yield right-of-way the model has a 0% precision.
# - When it comes to following too closely the model has a 45.4% precision.
# - When it comes to improper lane usage the model has a 0% precision.
# - For others the model has a 33.3% precision.

# %%
tree = DecisionTreeClassifier(criterion='entropy', random_state=1, max_depth=1)
abc = AdaBoostClassifier(base_estimator=tree, n_estimators=500, learning_rate=0.1, random_state=1)
pipe4 = Pipeline([('data_processing', processing_pipeline),('tree', abc)])
pipe4.fit(X_training,y_training)
abc_predicted = pipe4.predict(X_test)

# %%
print(classification_report(y_test, abc_predicted, digits=3))
# Out:
#                                 precision    recall  f1-score   support
#
# driver inattention/distraction      0.522     0.866     0.651     12589
#  failure to yield right-of-way      0.000     0.000     0.000      3444
#          following too closely      0.436     0.361     0.395      4853
#                          other      0.000     0.000     0.000      1986
# passing or lane usage improper      0.000     0.000     0.000      2047
#
#                       accuracy                          0.508     24919
#                      macro avg      0.192     0.245     0.209     24919
#                   weighted avg      0.349     0.508     0.406     24919

# %% [markdown]
# ### Observations
# - When we use a Adaboosting classifier to classify the contributing factor we get a macro average of 0.192
# - When it comes to driver's inattention the model has a 54% precision.
# - When it comes to failure to yield right-of-way the model has a 0% precision.
# - When it comes to following too closely the model has a 43.6% precision.
# - When it comes to improper lane usage the model has a 0% precision.
# - For others the model has a 0% precision.

# %% [markdown]
# ### Summary
# I would use random forest or logistic regression as the final model. As both of these model identify the less frequently occuring classes more accurately compared to the complex algorithms like gradient boosting algortihm or adaboosting algorithm.
